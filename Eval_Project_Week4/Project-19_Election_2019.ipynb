# %%
# importing the dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

# %%
# importing the dataset
df = pd.read_csv('ElectionData.csv',parse_dates=['time'])

# %%
df.head()
# Out:
#    TimeElapsed                time        territoryName  totalMandates  \
# 0            0 2019-10-06 20:10:02  Território Nacional              0
# 1            0 2019-10-06 20:10:02  Território Nacional              0
# 2            0 2019-10-06 20:10:02  Território Nacional              0
# 3            0 2019-10-06 20:10:02  Território Nacional              0
# 4            0 2019-10-06 20:10:02  Território Nacional              0
#
#    availableMandates  numParishes  numParishesApproved  blankVotes  \
# 0                226         3092                 1081        9652
# 1                226         3092                 1081        9652
# 2                226         3092                 1081        9652
# 3                226         3092                 1081        9652
# 4                226         3092                 1081        9652
#
#    blankVotesPercentage  nullVotes  ...  pre.votersPercentage  \
# 0                   2.5       8874  ...                 52.66
# ...

# %%
df.tail()
# Out:
#        TimeElapsed                time territoryName  totalMandates  \
# 21638          265 2019-10-07 00:35:01         Viseu              8
# 21639          265 2019-10-07 00:35:01         Viseu              8
# 21640          265 2019-10-07 00:35:01         Viseu              8
# 21641          265 2019-10-07 00:35:01         Viseu              8
# 21642          265 2019-10-07 00:35:01         Viseu              8
#
#        availableMandates  numParishes  numParishesApproved  blankVotes  \
# 21638                  0          277                  277        4995
# 21639                  0          277                  277        4995
# 21640                  0          277                  277        4995
# 21641                  0          277                  277        4995
# 21642                  0          277                  277        4995
#
#        blankVotesPercentage  nullVotes  ...  pre.votersPercentage  \
# ...

# %%
df.sample()
# Out:
#       TimeElapsed                time   territoryName  totalMandates  \
# 7262           90 2019-10-06 21:40:02  Castelo Branco              1
#
#       availableMandates  numParishes  numParishesApproved  blankVotes  \
# 7262                  3          120                  119        2079
#
#       blankVotesPercentage  nullVotes  ...  pre.votersPercentage  \
# 7262                  2.38       2097  ...                  57.4
#
#       pre.subscribedVoters  pre.totalVoters  Party  Mandates  Percentage  \
# 7262                169613            97365    PNR         0        0.27
#
#       validVotesPercentage  Votes  Hondt  FinalMandates
# 7262                  0.28    237      0              0
#
# [1 rows x 28 columns]

# %%
# shape of the dataset
df.shape
# Out:
# (21643, 28)

# %%
# columns of the dataset
df.columns
# Out:
# Index(['TimeElapsed', 'time', 'territoryName', 'totalMandates',
#        'availableMandates', 'numParishes', 'numParishesApproved', 'blankVotes',
#        'blankVotesPercentage', 'nullVotes', 'nullVotesPercentage',
#        'votersPercentage', 'subscribedVoters', 'totalVoters', 'pre.blankVotes',
#        'pre.blankVotesPercentage', 'pre.nullVotes', 'pre.nullVotesPercentage',
#        'pre.votersPercentage', 'pre.subscribedVoters', 'pre.totalVoters',
#        'Party', 'Mandates', 'Percentage', 'validVotesPercentage', 'Votes',
#        'Hondt', 'FinalMandates'],
#       dtype='object')

# %%
# info on the column datatype of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21643 entries, 0 to 21642
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   TimeElapsed               21643 non-null  int64
#  1   time                      21643 non-null  datetime64[ns]
#  2   territoryName             21643 non-null  object
#  3   totalMandates             21643 non-null  int64
#  4   availableMandates         21643 non-null  int64
#  5   numParishes               21643 non-null  int64
#  6   numParishesApproved       21643 non-null  int64
#  7   blankVotes                21643 non-null  int64
#  8   blankVotesPercentage      21643 non-null  float64
#  9   nullVotes                 21643 non-null  int64
#  10  nullVotesPercentage       21643 non-null  float64
#  11  votersPercentage          21643 non-null  float64
#  12  subscribedVoters          21643 non-null  int64
# ...

# %%
# description of the dataset
df.describe()
# Out:
#         TimeElapsed  totalMandates  availableMandates   numParishes  \
# count  21643.000000   21643.000000       21643.000000  21643.000000
# mean     133.146052      11.544795          11.499284    309.956013
# std       77.651193      31.314567          31.738783    659.055911
# min        0.000000       0.000000           0.000000     54.000000
# 25%       65.000000       1.000000           0.000000     75.000000
# 50%      135.000000       4.000000           3.000000    147.000000
# 75%      200.000000       9.000000           9.000000    242.000000
# max      265.000000     226.000000         226.000000   3092.000000
#
#        numParishesApproved     blankVotes  blankVotesPercentage     nullVotes  \
# count         21643.000000   21643.000000          21643.000000  21643.000000
# mean            261.090237    8875.066673              2.621629   6148.068752
# std             583.377428   21484.874088              0.795289  14735.469269
# ...

# %%
# checking for missing values
df.isna().sum()
# Out:
# TimeElapsed                 0
# time                        0
# territoryName               0
# totalMandates               0
# availableMandates           0
# numParishes                 0
# numParishesApproved         0
# blankVotes                  0
# blankVotesPercentage        0
# nullVotes                   0
# nullVotesPercentage         0
# votersPercentage            0
# subscribedVoters            0
# totalVoters                 0
# pre.blankVotes              0
# pre.blankVotesPercentage    0
# pre.nullVotes               0
# pre.nullVotesPercentage     0
# pre.votersPercentage        0
# pre.subscribedVoters        0
# pre.totalVoters             0
# Party                       0
# Mandates                    0
# Percentage                  0
# validVotesPercentage        0
# Votes                       0
# Hondt                       0
# FinalMandates               0
# dtype: int64

# %%
# checking for high correlation between features
df.corr()
# Out:
#                           TimeElapsed  totalMandates  availableMandates  \
# TimeElapsed                  1.000000       0.260377          -0.261627
# totalMandates                0.260377       1.000000           0.217404
# availableMandates           -0.261627       0.217404           1.000000
# numParishes                 -0.001944       0.765877           0.745472
# numParishesApproved          0.100432       0.873415           0.562719
# blankVotes                   0.192350       0.969988           0.390638
# blankVotesPercentage         0.034343      -0.003149          -0.002806
# nullVotes                    0.185784       0.967294           0.407366
# nullVotesPercentage         -0.225021      -0.165132           0.029915
# votersPercentage             0.029698       0.171317           0.112293
# subscribedVoters             0.195487       0.974407           0.385828
# totalVoters                  0.198243       0.976336           0.379093
# ...

# %%
# helper functions
def fig_of_size(x,y):
    return plt.figure(figsize=(x,y))

# %%
# plotting the correlations heatmap
fig_of_size(22,20)
sns.heatmap(df.corr(),annot=True)

# %% [markdown]
# * Initial Inferences:
#     * There are 28 total variables in this dataset.
#     * The dataset consists total of 21643 samples.
#     * There are no missing values in the dataset
#     * There are no high corelated (p > .90) features in the dataset.

# %% [markdown]
# ## EDA

# %%
df.head()
# Out:
#    TimeElapsed                time        territoryName  totalMandates  \
# 0            0 2019-10-06 20:10:02  Território Nacional              0
# 1            0 2019-10-06 20:10:02  Território Nacional              0
# 2            0 2019-10-06 20:10:02  Território Nacional              0
# 3            0 2019-10-06 20:10:02  Território Nacional              0
# 4            0 2019-10-06 20:10:02  Território Nacional              0
#
#    availableMandates  numParishes  numParishesApproved  blankVotes  \
# 0                226         3092                 1081        9652
# 1                226         3092                 1081        9652
# 2                226         3092                 1081        9652
# 3                226         3092                 1081        9652
# 4                226         3092                 1081        9652
#
#    blankVotesPercentage  nullVotes  ...  pre.votersPercentage  \
# 0                   2.5       8874  ...                 52.66
# ...

# %%
fig = fig_of_size(16,4)

fig.add_subplot(121)
sns.lineplot(df.TimeElapsed,df.Votes)

fig.add_subplot(122)
sns.pointplot(df.TimeElapsed,df.Votes)

# %%
# available mandatas vs total mandats

# %%
# helper function

def continous_variable_plots(col):
    
    fig = plt.figure(figsize=(16,6))
    
    fig.add_subplot(221)
    sns.distplot(col)
    fig.add_subplot(222)
    plt.hist(col)
    fig.add_subplot(223)
    sns.violinplot(col)
    fig.add_subplot(224)
    sns.boxplot(col)

# %%
df.totalMandates.value_counts()
# Out:
# 0      5055
# 3      2949
# 2      1755
# 9      1726
# 6      1419
#        ...
# 22       21
# 197      21
# 149      21
# 37       21
# 17       20
# Name: totalMandates, Length: 62, dtype: int64

# %%
df.availableMandates.value_counts()
# Out:
# 0      9686
# 3      1873
# 6      1201
# 9      1150
# 4      1089
#        ...
# 101      21
# 37       21
# 212      21
# 175      21
# 44       20
# Name: availableMandates, Length: 69, dtype: int64

# %%
sns.scatterplot(df.availableMandates,df.totalMandates)

# %%
# num Parishes and numParishesApproved

# %%
df.numParishesApproved.value_counts()
# Out:
# 69     1220
# 242     728
# 75      680
# 54      679
# 208     640
#        ...
# 83       16
# 188      16
# 171      16
# 170      16
# 180      16
# Name: numParishesApproved, Length: 219, dtype: int64

# %%
continous_variable_plots(df.numParishes)

# %%
continous_variable_plots(df.numParishesApproved)

# %%
fig_of_size(16,4)
sns.distplot(df.numParishes,label='Total Parishes')
sns.distplot(df.numParishesApproved,label='Parishes Approved')
plt.legend()

# %%
df[df.numParishes > 500]
# Out:
#        TimeElapsed                time        territoryName  totalMandates  \
# 0                0 2019-10-06 20:10:02  Território Nacional              0
# 1                0 2019-10-06 20:10:02  Território Nacional              0
# 2                0 2019-10-06 20:10:02  Território Nacional              0
# 3                0 2019-10-06 20:10:02  Território Nacional              0
# 4                0 2019-10-06 20:10:02  Território Nacional              0
# ...            ...                 ...                  ...            ...
# 21256          265 2019-10-07 00:35:01  Território Nacional            226
# 21257          265 2019-10-07 00:35:01  Território Nacional            226
# 21258          265 2019-10-07 00:35:01  Território Nacional            226
# 21259          265 2019-10-07 00:35:01  Território Nacional            226
# 21260          265 2019-10-07 00:35:01  Território Nacional            226
#
# ...

# %%
df[df.numParishes > 500].territoryName.value_counts()
# Out:
# Território Nacional    1134
# Name: territoryName, dtype: int64

# %% [markdown]
# * most of the teritorries have parishes under 500, but the territory Território Nacional have over 3000

# %%
# blank Votes and their percentage
df.blankVotes.value_counts()
# Out:
# 1371    716
# 2026    665
# 3617    640
# 697     620
# 1680    608
#        ...
# 1870     16
# 1561     16
# 1722     16
# 2237     16
# 2241     16
# Name: blankVotes, Length: 329, dtype: int64

# %%
continous_variable_plots(df.blankVotes)

# %%
pd.set_option('display.max_columns',None)

# %%
df
# Out:
#        TimeElapsed                time        territoryName  totalMandates  \
# 0                0 2019-10-06 20:10:02  Território Nacional              0
# 1                0 2019-10-06 20:10:02  Território Nacional              0
# 2                0 2019-10-06 20:10:02  Território Nacional              0
# 3                0 2019-10-06 20:10:02  Território Nacional              0
# 4                0 2019-10-06 20:10:02  Território Nacional              0
# ...            ...                 ...                  ...            ...
# 21638          265 2019-10-07 00:35:01                Viseu              8
# 21639          265 2019-10-07 00:35:01                Viseu              8
# 21640          265 2019-10-07 00:35:01                Viseu              8
# 21641          265 2019-10-07 00:35:01                Viseu              8
# 21642          265 2019-10-07 00:35:01                Viseu              8
#
# ...

# %%
# total votes vs subscibed votees

# %%
fig_of_size(16,4)
sns.distplot(df.totalVoters)
sns.distplot(df.subscribedVoters)
#df[['totalVoters','subscribedVoters']].plot(kind='hist')

# %%
# preblank votes ans blank votes

# %%
fig_of_size(16,4)
sns.kdeplot(df['pre.blankVotes'])
sns.kdeplot(df.blankVotes)

# %%
# territories

# %%
df.head()
# Out:
#    TimeElapsed                time        territoryName  totalMandates  \
# 0            0 2019-10-06 20:10:02  Território Nacional              0
# 1            0 2019-10-06 20:10:02  Território Nacional              0
# 2            0 2019-10-06 20:10:02  Território Nacional              0
# 3            0 2019-10-06 20:10:02  Território Nacional              0
# 4            0 2019-10-06 20:10:02  Território Nacional              0
#
#    availableMandates  numParishes  numParishesApproved  blankVotes  \
# 0                226         3092                 1081        9652
# 1                226         3092                 1081        9652
# 2                226         3092                 1081        9652
# 3                226         3092                 1081        9652
# 4                226         3092                 1081        9652
#
#    blankVotesPercentage  nullVotes  nullVotesPercentage  votersPercentage  \
# ...

# %%
df_terr = df.groupby('territoryName').mean()

# %%
px.bar(df_terr.sort_values('Votes'),x='Votes',color='votersPercentage')
# Out:
# <div>
#
#
#             <div id="48451fb4-7d2f-4ecf-8961-39f234ed93b6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("48451fb4-7d2f-4ecf-8961-39f234ed93b6")) {
#                     Plotly.newPlot(
#                         '48451fb4-7d2f-4ecf-8961-39f234ed93b6',
# ...

# %%
df_terr
# Out:
#                      TimeElapsed  totalMandates  availableMandates  \
# territoryName
# Aveiro                     132.5       7.944444           8.055556
# Açores                     150.0       3.319149           1.680851
# Beja                       132.5       2.277778           0.722222
# Braga                      132.5      11.962963           7.037037
# Bragança                   132.5       1.611111           1.388889
# Castelo Branco             132.5       2.555556           1.444444
# Coimbra                    132.5       5.074074           3.925926
# Faro                       132.5       5.314815           3.685185
# Guarda                     132.5       2.000000           1.000000
# Leiria                     132.5       5.259259           4.740741
# Lisboa                     132.5      16.592593          31.407407
# Madeira                    132.5       3.814815           2.185185
# Portalegre                 132.5       1.296296           0.703704
# ...

# %%
len(df_terr)
# Out:
# 21

# %%
df_terr.sort_values('Votes',ascending=False).iloc[:,2:12].style.background_gradient(cmap='viridis')
# Out:
# <style  type="text/css" >
#     #T_0ba99363_0d44_11eb_8057_e0d55e095987row0_col0 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_0ba99363_0d44_11eb_8057_e0d55e095987row0_col1 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_0ba99363_0d44_11eb_8057_e0d55e095987row0_col2 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_0ba99363_0d44_11eb_8057_e0d55e095987row0_col3 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_0ba99363_0d44_11eb_8057_e0d55e095987row0_col4 {
#             background-color:  #228c8d;
#             color:  #000000;
#         }    #T_0ba99363_0d44_11eb_8057_e0d55e095987row0_col5 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_0ba99363_0d44_11eb_8057_e0d55e095987row0_col6 {
#             background-color:  #2a768e;
#             color:  #f1f1f1;
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21643 entries, 0 to 21642
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   TimeElapsed               21643 non-null  int64
#  1   time                      21643 non-null  datetime64[ns]
#  2   territoryName             21643 non-null  object
#  3   totalMandates             21643 non-null  int64
#  4   availableMandates         21643 non-null  int64
#  5   numParishes               21643 non-null  int64
#  6   numParishesApproved       21643 non-null  int64
#  7   blankVotes                21643 non-null  int64
#  8   blankVotesPercentage      21643 non-null  float64
#  9   nullVotes                 21643 non-null  int64
#  10  nullVotesPercentage       21643 non-null  float64
#  11  votersPercentage          21643 non-null  float64
#  12  subscribedVoters          21643 non-null  int64
# ...

# %%
# Party

# %%
df.Party.value_counts()
# Out:
# PAN          1127
# PCP-PEV      1127
# B.E.         1127
# IL           1127
# CH           1127
# A            1127
# PPD/PSD      1127
# PNR          1127
# L            1127
# PCTP/MRPP    1127
# PS           1127
# CDS-PP       1127
# PDR          1127
# PPM          1073
# R.I.R.       1026
# PTP          1019
# MPT          1019
# PURP          972
# NC            972
# JPP           486
# MAS           425
# Name: Party, dtype: int64

# %%
fig_of_size(16,4)
sns.countplot(df.Party)

# %%
df_party = df.groupby('Party').mean()

# %%
px.bar(df_party)
# Out:
# <div>
#
#
#             <div id="e5ddd395-a9ec-4938-936b-94c74bdcfbe8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e5ddd395-a9ec-4938-936b-94c74bdcfbe8")) {
#                     Plotly.newPlot(
#                         'e5ddd395-a9ec-4938-936b-94c74bdcfbe8',
# ...

# %%
df_party
# Out:
#            TimeElapsed  totalMandates  availableMandates  numParishes  \
# Party
# A           133.229814      10.859805          10.766637   295.336291
# B.E.        133.229814      10.859805          10.766637   295.336291
# CDS-PP      133.229814      10.859805          10.766637   295.336291
# CH          133.229814      10.859805          10.766637   295.336291
# IL          133.229814      10.859805          10.766637   295.336291
# JPP         132.500000      19.590535          18.187243   514.777778
# L           133.229814      10.859805          10.766637   295.336291
# MAS         134.435294      22.797647          24.767059   542.767059
# MPT         133.307164      11.750736          11.743867   304.221786
# NC          132.500000      12.217078          12.282922   324.388889
# PAN         133.229814      10.859805          10.766637   295.336291
# PCP-PEV     133.229814      10.859805          10.766637   295.336291
# ...

# %%
df_party.sort_values('Votes').iloc[:,2:12].style.background_gradient(cmap='viridis')
# Out:
# <style  type="text/css" >
#     #T_c2082789_0d45_11eb_8a9d_e0d55e095987row0_col0 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_c2082789_0d45_11eb_8a9d_e0d55e095987row0_col1 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_c2082789_0d45_11eb_8a9d_e0d55e095987row0_col2 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_c2082789_0d45_11eb_8a9d_e0d55e095987row0_col3 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_c2082789_0d45_11eb_8a9d_e0d55e095987row0_col4 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_c2082789_0d45_11eb_8a9d_e0d55e095987row0_col5 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_c2082789_0d45_11eb_8a9d_e0d55e095987row0_col6 {
#             background-color:  #440154;
#             color:  #f1f1f1;
# ...

# %%
fig_of_size(16,4)
sns.barplot('Party','Percentage',data = df_party.sort_values('Percentage',ascending=False).reset_index())

# %%
# mandates

# %%
continous_variable_plots(df.Mandates)

# %%
# territory wise final mandates
for terr in list(df_terr.index):
    fig_of_size(12,3)
    sns.violinplot(df[df.territoryName == terr ].FinalMandates)
    plt.title(terr)

# %%
# territory with highest mandates and lowest mandates

# %%
df_terr.FinalMandates.idxmax()
# Out:
# 'Território Nacional'

# %%
df_terr.FinalMandates.idxmin()
# Out:
# 'Portalegre'

# %%
# hondth and mandates

# %%
continous_variable_plots(df.Hondt)

# %% [markdown]
# ## Removing the outliers from the dataset

# %%
df.head()
# Out:
#    TimeElapsed                time        territoryName  totalMandates  \
# 0            0 2019-10-06 20:10:02  Território Nacional              0
# 1            0 2019-10-06 20:10:02  Território Nacional              0
# 2            0 2019-10-06 20:10:02  Território Nacional              0
# 3            0 2019-10-06 20:10:02  Território Nacional              0
# 4            0 2019-10-06 20:10:02  Território Nacional              0
#
#    availableMandates  numParishes  numParishesApproved  blankVotes  \
# 0                226         3092                 1081        9652
# 1                226         3092                 1081        9652
# 2                226         3092                 1081        9652
# 3                226         3092                 1081        9652
# 4                226         3092                 1081        9652
#
#    blankVotesPercentage  nullVotes  nullVotesPercentage  votersPercentage  \
# ...

# %%
df['hour_of_day'] = df['time'].apply(lambda x: x.hour)

# %%
df
# Out:
#        TimeElapsed                time        territoryName  totalMandates  \
# 0                0 2019-10-06 20:10:02  Território Nacional              0
# 1                0 2019-10-06 20:10:02  Território Nacional              0
# 2                0 2019-10-06 20:10:02  Território Nacional              0
# 3                0 2019-10-06 20:10:02  Território Nacional              0
# 4                0 2019-10-06 20:10:02  Território Nacional              0
# ...            ...                 ...                  ...            ...
# 21638          265 2019-10-07 00:35:01                Viseu              8
# 21639          265 2019-10-07 00:35:01                Viseu              8
# 21640          265 2019-10-07 00:35:01                Viseu              8
# 21641          265 2019-10-07 00:35:01                Viseu              8
# 21642          265 2019-10-07 00:35:01                Viseu              8
#
# ...

# %%
# seperating the num and cat variables

# %%
from feature_engine.missing_data_imputers import _find_categorical_variables,_find_numerical_variables
cat_var = _find_categorical_variables(df)
num_var = _find_numerical_variables(df)

# %%
for col in num_var:
    fig_of_size(16,4)
    sns.boxplot(df[col])

# %%
# addressing the outliers using z score

# %%
# creating a copy of the raw datafrome for preprocessing.
df_cleaned = df.copy()

# %%
z_scores = stats.zscore(df_cleaned[num_var])

abs_z_scores = np.abs(z_scores)

filtered_entries = (abs_z_scores < 3).all(axis=1)

df_cleaned = df_cleaned[filtered_entries]

# %%
df_cleaned
# Out:
#        TimeElapsed                time territoryName  totalMandates  \
# 22               0 2019-10-06 20:10:02        Aveiro              0
# 23               0 2019-10-06 20:10:02        Aveiro              0
# 24               0 2019-10-06 20:10:02        Aveiro              0
# 25               0 2019-10-06 20:10:02        Aveiro              0
# 26               0 2019-10-06 20:10:02        Aveiro              0
# ...            ...                 ...           ...            ...
# 21638          265 2019-10-07 00:35:01         Viseu              8
# 21639          265 2019-10-07 00:35:01         Viseu              8
# 21640          265 2019-10-07 00:35:01         Viseu              8
# 21641          265 2019-10-07 00:35:01         Viseu              8
# 21642          265 2019-10-07 00:35:01         Viseu              8
#
#        availableMandates  numParishes  numParishesApproved  blankVotes  \
# 22                    16          147                   12         186
# ...

# %%
len(df_cleaned)
# Out:
# 18333

# %%
len(df)
# Out:
# 21643

# %%
21643-18333
# Out:
# 3310

# %%
3310 / len(df) * 100
# Out:
# 15.293628424894884

# %%
# before and after addresing the outliers
for col in num_var:
    fig = fig_of_size(16,4)
    
    fig.add_subplot(121)
    sns.boxplot(df[col])
    fig.add_subplot(122)
    sns.boxplot(df_cleaned[col])

# %%
# The latter features looks better than the original ones.

# %%
## addressing the skew of the features

# %%
for col in num_var:
    fig_of_size(16,4)
    sns.distplot(df[col])

# %%
# skew stats

# %%
df_cleaned.skew()
# Out:
# TimeElapsed                -0.024110
# totalMandates               2.542453
# availableMandates           2.593527
# numParishes                 0.585363
# numParishesApproved         0.619329
# blankVotes                  1.800122
# blankVotesPercentage       -0.844508
# nullVotes                   2.103352
# nullVotesPercentage         0.564426
# votersPercentage           -0.392023
# subscribedVoters            2.407541
# totalVoters                 2.468630
# pre.blankVotes              2.034860
# pre.blankVotesPercentage   -0.410446
# pre.nullVotes               2.340000
# pre.nullVotesPercentage     1.033803
# pre.votersPercentage       -0.514215
# pre.subscribedVoters        2.370988
# pre.totalVoters             2.468950
# Mandates                    7.177093
# Percentage                  3.373567
# validVotesPercentage        3.383145
# Votes                       7.310058
# Hondt                       7.012845
# FinalMandates               6.746120
# ...

# %%
# adressing some skews

# %%
# try1 : log transformation
np.log1p(df_cleaned[num_var]).skew()
# Out:
# TimeElapsed                -2.117267
# totalMandates               0.020702
# availableMandates           0.503375
# numParishes                -0.138265
# numParishesApproved        -1.099103
# blankVotes                 -0.592756
# blankVotesPercentage       -1.948591
# nullVotes                  -0.880145
# nullVotesPercentage         0.329675
# votersPercentage           -0.574225
# subscribedVoters           -0.772107
# totalVoters                -0.647681
# pre.blankVotes             -0.642916
# pre.blankVotesPercentage   -1.032230
# pre.nullVotes              -0.937998
# pre.nullVotesPercentage     0.628444
# pre.votersPercentage       -0.605547
# pre.subscribedVoters       -0.802802
# pre.totalVoters            -0.670218
# Mandates                    4.479200
# Percentage                  1.565493
# validVotesPercentage        1.550088
# Votes                       0.268973
# Hondt                       3.488567
# FinalMandates               3.368168
# ...

# %%
# try2 Square root transformation
np.log1p(df_cleaned[num_var]).skew()
# Out:
# TimeElapsed                -2.117267
# totalMandates               0.020702
# availableMandates           0.503375
# numParishes                -0.138265
# numParishesApproved        -1.099103
# blankVotes                 -0.592756
# blankVotesPercentage       -1.948591
# nullVotes                  -0.880145
# nullVotesPercentage         0.329675
# votersPercentage           -0.574225
# subscribedVoters           -0.772107
# totalVoters                -0.647681
# pre.blankVotes             -0.642916
# pre.blankVotesPercentage   -1.032230
# pre.nullVotes              -0.937998
# pre.nullVotesPercentage     0.628444
# pre.votersPercentage       -0.605547
# pre.subscribedVoters       -0.802802
# pre.totalVoters            -0.670218
# Mandates                    4.479200
# Percentage                  1.565493
# validVotesPercentage        1.550088
# Votes                       0.268973
# Hondt                       3.488567
# FinalMandates               3.368168
# ...

# %%
# try 3 : cbrt transforation
np.log1p(df_cleaned[num_var]).skew()
# Out:
# TimeElapsed                -2.117267
# totalMandates               0.020702
# availableMandates           0.503375
# numParishes                -0.138265
# numParishesApproved        -1.099103
# blankVotes                 -0.592756
# blankVotesPercentage       -1.948591
# nullVotes                  -0.880145
# nullVotesPercentage         0.329675
# votersPercentage           -0.574225
# subscribedVoters           -0.772107
# totalVoters                -0.647681
# pre.blankVotes             -0.642916
# pre.blankVotesPercentage   -1.032230
# pre.nullVotes              -0.937998
# pre.nullVotesPercentage     0.628444
# pre.votersPercentage       -0.605547
# pre.subscribedVoters       -0.802802
# pre.totalVoters            -0.670218
# Mandates                    4.479200
# Percentage                  1.565493
# validVotesPercentage        1.550088
# Votes                       0.268973
# Hondt                       3.488567
# FinalMandates               3.368168
# ...

# %%
pd.DataFrame(list(zip(df.skew(),np.log1p(df_cleaned[num_var]).skew(),np.sqrt(df_cleaned[num_var]).skew(),np.cbrt(df_cleaned[num_var]).skew())),columns=['RAW','log','sqrt','cbrt'])
# Out:
#           RAW       log      sqrt      cbrt
# 0   -0.005496 -2.117267 -0.686604 -1.218975
# 1    5.150031  0.020702  0.634916 -0.222084
# 2    5.131572  0.503375  0.998395  0.432866
# 3    3.920433 -0.138265  0.205230  0.084848
# 4    4.238343 -1.099103 -0.034540 -0.336032
# 5    4.521940 -0.592756  0.787531  0.387392
# 6    0.069627 -1.948591 -1.720172 -2.039638
# 7    4.520945 -0.880145  0.849666  0.325546
# 8    0.855419  0.329675  0.388073  0.328317
# 9   -1.158029 -0.574225 -0.485266 -0.516186
# 10   4.568797 -0.772107  1.042935  0.476920
# 11   4.541364 -0.647681  1.169783  0.614675
# 12   4.551489 -0.642916  0.868433  0.420701
# 13   0.021609 -1.032230 -0.905180 -1.084636
# 14   4.563235 -0.937998  0.869955  0.294521
# 15   1.231109  0.628444  0.721158  0.618481
# 16  -0.779289 -0.605547 -0.560612 -0.576132
# 17   4.565085 -0.802802  1.007046  0.441791
# 18   4.548030 -0.670218  1.150252  0.591293
# 19  16.576658  4.479200  4.344943  3.798247
# ...

# %%
# let's finalize the log transfoation as it is giving the best resul;ts

# %%
df_cleaned[num_var] = np.log1p(df_cleaned[num_var])

# %%
# beofre and after - skew transformation
for col in num_var:
    fig = fig_of_size(16,4)
    
    fig.add_subplot(121)
    sns.distplot(df[col])
    fig.add_subplot(122)
    sns.distplot(df_cleaned[col])

# %% [markdown]
# ## One hot encoding the categorical variables.

# %%
cat_var
# Out:
# ['territoryName', 'Party']

# %%
from feature_engine.categorical_encoders import OneHotCategoricalEncoder

# %%
ohc = OneHotCategoricalEncoder(variables=cat_var,drop_last=True)

# %%
df_cleaned = ohc.fit_transform(df_cleaned)

# %%
df_cleaned
# Out:
#        TimeElapsed                time  totalMandates  availableMandates  \
# 22        0.000000 2019-10-06 20:10:02       0.000000           2.833213
# 23        0.000000 2019-10-06 20:10:02       0.000000           2.833213
# 24        0.000000 2019-10-06 20:10:02       0.000000           2.833213
# 25        0.000000 2019-10-06 20:10:02       0.000000           2.833213
# 26        0.000000 2019-10-06 20:10:02       0.000000           2.833213
# ...            ...                 ...            ...                ...
# 21638     5.583496 2019-10-07 00:35:01       2.197225           0.000000
# 21639     5.583496 2019-10-07 00:35:01       2.197225           0.000000
# 21640     5.583496 2019-10-07 00:35:01       2.197225           0.000000
# 21641     5.583496 2019-10-07 00:35:01       2.197225           0.000000
# 21642     5.583496 2019-10-07 00:35:01       2.197225           0.000000
#
#        numParishes  numParishesApproved  blankVotes  blankVotesPercentage  \
# ...

# %%
df_cleaned
# Out:
#        TimeElapsed                time  totalMandates  availableMandates  \
# 22        0.000000 2019-10-06 20:10:02       0.000000           2.833213
# 23        0.000000 2019-10-06 20:10:02       0.000000           2.833213
# 24        0.000000 2019-10-06 20:10:02       0.000000           2.833213
# 25        0.000000 2019-10-06 20:10:02       0.000000           2.833213
# 26        0.000000 2019-10-06 20:10:02       0.000000           2.833213
# ...            ...                 ...            ...                ...
# 21638     5.583496 2019-10-07 00:35:01       2.197225           0.000000
# 21639     5.583496 2019-10-07 00:35:01       2.197225           0.000000
# 21640     5.583496 2019-10-07 00:35:01       2.197225           0.000000
# 21641     5.583496 2019-10-07 00:35:01       2.197225           0.000000
# 21642     5.583496 2019-10-07 00:35:01       2.197225           0.000000
#
#        numParishes  numParishesApproved  blankVotes  blankVotesPercentage  \
# ...

# %% [markdown]
# ## X and y split

# %%
X = df_cleaned.drop(['time','FinalMandates'],1)
y = df_cleaned.FinalMandates

# %%
X.shape,y.shape
# Out:
# ((18333, 63), (18333,))

# %% [markdown]
# ## Train and Test split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %%
X_train.shape,y_train.shape,X_test.shape,y_test.shape
# Out:
# ((12833, 63), (12833,), (5500, 63), (5500,))

# %% [markdown]
# ## Standard Scaling

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer

# %%
num_var.remove('FinalMandates')

# %%
num_var
# Out:
# ['TimeElapsed',
#  'totalMandates',
#  'availableMandates',
#  'numParishes',
#  'numParishesApproved',
#  'blankVotes',
#  'blankVotesPercentage',
#  'nullVotes',
#  'nullVotesPercentage',
#  'votersPercentage',
#  'subscribedVoters',
#  'totalVoters',
#  'pre.blankVotes',
#  'pre.blankVotesPercentage',
#  'pre.nullVotes',
#  'pre.nullVotesPercentage',
#  'pre.votersPercentage',
#  'pre.subscribedVoters',
#  'pre.totalVoters',
#  'Mandates',
#  'Percentage',
#  'validVotesPercentage',
#  'Votes',
#  'Hondt',
#  'hour_of_day']

# %%
ct = ColumnTransformer(transformers=[('sc',StandardScaler(),num_var)],remainder='passthrough')

# %%
X_train = ct.fit_transform(X_train)
X_test = ct.transform(X_test)

# %%
X_train.shape,X_test.shape
# Out:
# ((12833, 63), (5500, 63))

# %% [markdown]
# ## Building the model

# %%
# import training dependencies
from sklearn.linear_model import LinearRegression,Ridge,Lasso,ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor

# %%
# importing the evaluation metrics
from sklearn.model_selection import cross_val_score,KFold
from sklearn.metrics import r2_score,mean_squared_error

# %%
# helper function
def train_n_ret_scores(model):
    model.fit(X_train,y_train)
    y_preds = model.predict(X_test)
    
    print('R2_score',r2_score(y_test,y_preds))
    print('MSE',mean_squared_error(y_test,y_preds))

# %%
# try1: Linear Regression
train_n_ret_scores(LinearRegression())
# Out:
# R2_score 0.9795568067240837
# MSE 0.003690932103497862

# %%
# try2: Ridge Regression
train_n_ret_scores(Ridge(alpha=0.001))
# Out:
# R2_score 0.9795502803897395
# MSE 0.0036921104055676265

# %%
# try3: Lasso Regression
train_n_ret_scores(Lasso(alpha=0.00003))
# Out:
# R2_score 0.9796098587810591
# MSE 0.00368135377893751

# %%
# ElasticNet
train_n_ret_scores(ElasticNet(alpha=0.0001))
# Out:
# R2_score 0.9796294895735544
# MSE 0.003677809522359764

# %%
# try4: SVR
train_n_ret_scores(SVR())
# Out:
# R2_score 0.9786525191502056
# MSE 0.003854197401251184

# %%
# try5: Decision Trees
train_n_ret_scores(DecisionTreeRegressor(criterion='mse'))
# Out:
# R2_score 0.9996870742026701
# MSE 5.649742952527829e-05

# %%
# try6: Random Forest
train_n_ret_scores(RandomForestRegressor())
# Out:
# R2_score 0.9991878648831483
# MSE 0.00014662756129677374

# %%
# try7: Gradient Boosting
train_n_ret_scores(GradientBoostingRegressor())
# Out:
# R2_score 0.9912814475311027
# MSE 0.0015740977825315502

# %%
#let's create the models dataframe
models = [LinearRegression(),Ridge(alpha=0.001),Lasso(alpha=0.0003),ElasticNet(alpha=0.0001),SVR(),DecisionTreeRegressor(),RandomForestRegressor(),GradientBoostingRegressor(),AdaBoostRegressor(base_estimator=LinearRegression())]
model_names = 'Linear Ridge Lasso ElasticNet SVR Descision_Tree Random_Forest Gradient_Boost Ada_Boost'.split()
models_df = pd.DataFrame(columns=['Model','MSE','R2','meanCV'])
for model,model_names in zip(models,model_names):
    print(model)
    
    model.fit(X_train,y_train)
    
    y_preds = model.predict(X_test)
    
    mse = mean_squared_error(y_test,y_preds)
    r2 = r2_score(y_test,y_preds)
    avgCV = np.mean(cross_val_score(model,X,y,scoring='r2'))
    
    
    models_df = models_df.append({'Model':model_names,'MSE':mse,'R2':r2,'meanCV':avgCV},ignore_index=True)
# Out:
# LinearRegression()
# Ridge(alpha=0.001)
# Lasso(alpha=0.0003)
# ElasticNet(alpha=0.0001)
# SVR()
# DecisionTreeRegressor()
# RandomForestRegressor()
# GradientBoostingRegressor()
# AdaBoostRegressor(base_estimator=LinearRegression())

# %%
models_df
# Out:
#             Model       MSE        R2    meanCV
# 0          Linear  0.003691  0.979557  0.941216
# 1           Ridge  0.003692  0.979550  0.973320
# 2           Lasso  0.003693  0.979546  0.978295
# 3      ElasticNet  0.003678  0.979629  0.977274
# 4             SVR  0.003854  0.978653  0.942446
# 5  Descision_Tree  0.000056  0.999687  0.977736
# 6   Random_Forest  0.000157  0.999128  0.983865
# 7  Gradient_Boost  0.001573  0.991288  0.984605
# 8       Ada_Boost  0.012649  0.929940  0.934158

# %% [markdown]
# * Ensemble Techniques works great in this problem.

# %% [markdown]
# * Gradient Techniques gives us the best cross val score

# %%
best_model = GradientBoostingRegressor()

# %%
best_model.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor()

# %%
y_test = best_model.predict(X_test)

# %%
train_n_ret_scores(best_model)
# Out:
# R2_score 0.9999951765393236
# MSE 8.588841620024966e-07

# %%
## Saving the model

# %%
import joblib
joblib.dump(best_model,'Election_2019.pkl')
# Out:
# ['Election_2019.pkl']
